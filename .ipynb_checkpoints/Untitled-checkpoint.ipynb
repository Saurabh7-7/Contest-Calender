# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
a=np.array(4)

# %%
a
# Out:
# array(4)

# %%
a.ndim
# Out:
# 0

# %%
a=np.array([[[1,2],[3,4]],[[5,6],[7,8]]])
a
# Out:
# array([[[1, 2],
#         [3, 4]],
#
#        [[5, 6],
#         [7, 8]]])

# %%
df = pd.read_csv('datasets/placement-dataset.csv')
df= df.iloc[:,1:]

# %%
df.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   NaN  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   cgpa       92 non-null     float64
#  1   iq         96 non-null     float64
#  2   placement  100 non-null    int64
# dtypes: float64(2), int64(1)
# memory usage: 2.5 KB

# %%
df.shape
# Out:
# (100, 3)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   cgpa       92 non-null     float64
#  1   iq         96 non-null     float64
#  2   placement  100 non-null    int64
# dtypes: float64(2), int64(1)
# memory usage: 2.5 KB

# %%
df=df.dropna()

# %%
plt.scatter(df['cgpa'],df['iq'],c=df['placement'])

# %%
X=df.iloc[:,0:2]
y=df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
 X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.11)

# %%
y_test
# Out:
# 41    0
# 20    1
# 4     0
# 42    1
# 47    0
# 40    0
# 1     0
# 70    1
# 19    0
# 22    0
# Name: placement, dtype: int64

# %%
scaler=StandardScaler()
X_train = scaler.fit_transform(X_train)

# %%
X_test = scaler.transform(X_test)

# %%
X_test
# Out:
# array([[-0.5274398 , -0.21511643],
#        [ 0.47802589, -0.07663708],
#        [-0.19228457,  0.43112055],
#        [ 1.31591397, -0.79211373],
#        [-0.69501742,  0.86963849],
#        [-0.94638384,  0.24648141],
#        [-0.10849576, -0.39975557],
#        [ 0.22665947,  0.08492217],
#        [-0.69501742,  0.20032163],
#        [-0.94638384, -0.07663708]])

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression()

# %%
clf.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_predict = clf.predict(X_test)

# %%
from  sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_predict)
# Out:
# 1.0

# %%
from mlxtend.plotting import plot_decision_regions

plot_decision_regions(X_train, y_train.values, clf=clf, legend=2)
# Out:
# <Axes: >

# %%
import pickle

# %%
pickle.dump(clf,open('model.pkl','wb'))

# %%
import requests
from io import StringIO
url ="https://drive.google.com/uc?id=107Sqmt1sk6oGcKL_TwNVqz5wMJBavsoq&export=download"
header={"User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; rv:66.0) Gecko/20100101 Firefox/66.0"}
req = requests.get(url,headers=header)
data=StringIO(req.text)

df = pd.read_csv(data)

# %%
df.head()
# Out:
#    Index                                  Name  \
# 0      1  Compact Printer Air Advanced Digital
# 1      2                                Tablet
# 2      3                  Smart Blender Cooker
# 3      4          Advanced Router Rechargeable
# 4      5          Portable Mouse Monitor Phone
#
#                                          Description  \
# 0      Situation organization these memory much off.
# 1        Discussion loss politics free one thousand.
# 2                                  No situation per.
# 3                    For force gas energy six laugh.
# 4  Feeling back religious however author room sci...
#
#                         Brand            Category  Price Currency  Stock  \
# 0     Garner, Boyle and Flynn  Books & Stationery    265      USD    774
# 1                 Mueller Inc    Shoes & Footwear    502      USD     81
# 2  Lawson, Keller and Winters  Kitchen Appliances    227      USD    726
# ...

# %%
pd.read_json("datasets/train.json")
# Out:
#           id      cuisine                                        ingredients
# 0      10259        greek  [romaine lettuce, black olives, grape tomatoes...
# 1      25693  southern_us  [plain flour, ground pepper, salt, tomatoes, g...
# 2      20130     filipino  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3      22213       indian                [water, vegetable oil, wheat, salt]
# 4      13162       indian  [black pepper, shallots, cornflour, cayenne pe...
# ...      ...          ...                                                ...
# 39769  29109        irish  [light brown sugar, granulated sugar, butter, ...
# 39770  11462      italian  [KRAFT Zesty Italian Dressing, purple onion, b...
# 39771   2238        irish  [eggs, citrus fruit, raisins, sourdough starte...
# 39772  41882      chinese  [boneless chicken skinless thigh, minced garli...
# 39773   2362      mexican  [green chile, jalapeno chilies, onions, ground...
#
# [39774 rows x 3 columns]

# %%
import mysql.connector

# %%
con = mysql.connector.connect(host='127.0.0.1',port='3307',user='root', password='rootpass',database='world')

# %%
pd.read_sql_query("SELECT * FROM city",con)
# Out:
# /var/folders/rq/xv368xl14tb36lwn828xhbj00000gn/T/ipykernel_11811/4254107751.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("SELECT * FROM city",con)
#         ID            Name CountryCode       District  Population
# 0        1           Kabul         AFG          Kabol     1780000
# 1        2        Qandahar         AFG       Qandahar      237500
# 2        3           Herat         AFG          Herat      186800
# 3        4  Mazar-e-Sharif         AFG          Balkh      127800
# 4        5       Amsterdam         NLD  Noord-Holland      731200
# ...    ...             ...         ...            ...         ...
# 4074  4075      Khan Yunis         PSE     Khan Yunis      123175
# 4075  4076          Hebron         PSE         Hebron      119401
# ...

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine(
    "mysql+pymysql://root:rootpass@127.0.0.1:3307/world"
)

# %%
sqlchemy = pd.read_sql_query("SELECT * FROM city", engine)

print(sqlchemy.head())
# Out:
#    ID            Name CountryCode       District  Population
# 0   1           Kabul         AFG          Kabol     1780000
# 1   2        Qandahar         AFG       Qandahar      237500
# 2   3           Herat         AFG          Herat      186800
# 3   4  Mazar-e-Sharif         AFG          Balkh      127800
# 4   5       Amsterdam         NLD  Noord-Holland      731200

# %%
df = pd.DataFrame() 
for i in range(1,400):
    url = f"https://api.themoviedb.org/3/movie/top_rated?language=en-US&page={i}"
    headers = {
        "accept": "application/json",
        "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiIxNWJiODg4Zjk1MjFjM2IxZGNhNGY5NDM5NWUwZTRkZCIsIm5iZiI6MTc5MDI1ODYzNy40Njg5OTk5LCJzdWIiOiI2YWI1MmRjZGE3NmE4ZDg0OWM2MTY0YzUiLCJzY29wZXMiOlsiYXBpX3JlYWQiXSwidmVyc2lvbiI6MX0.4m0BRpnMzxntTMF1szQuWW1-LBwIuJpIxvFMyWFzLyI"
    }
    response = requests.get(url, headers=headers)
    temp_df=pd.DataFrame(response.json()['results'])
    df=pd.concat([df,temp_df],ignore_index=True)

print(1)
# Out:
# 1

# %%
for i in range(400,500):
    url = f"https://api.themoviedb.org/3/movie/top_rated?language=en-US&page={i}"
    headers = {
        "accept": "application/json",
        "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiIxNWJiODg4Zjk1MjFjM2IxZGNhNGY5NDM5NWUwZTRkZCIsIm5iZiI6MTc5MDI1ODYzNy40Njg5OTk5LCJzdWIiOiI2YWI1MmRjZGE3NmE4ZDg0OWM2MTY0YzUiLCJzY29wZXMiOlsiYXBpX3JlYWQiXSwidmVyc2lvbiI6MX0.4m0BRpnMzxntTMF1szQuWW1-LBwIuJpIxvFMyWFzLyI"
    }
    response = requests.get(url, headers=headers)
    temp_df=pd.DataFrame(response.json()['results'])
    df=pd.concat([df,temp_df],ignore_index=True)

print(1)
# Out:
# 1

# %%
df=df.drop(columns=['softcore','original_title','genre_ids'])

# %%
df
# Out:
#       adult       id                                           title  \
# 0     False  1560520           Batman: Knightfall Part 1: Knightfall
# 1     False   980431                 Avatar Aang: The Last Airbender
# 2     False  1007757                                         Swapped
# 3     False  1632181                             Accidental Partners
# 4     False  1311031  Demon Slayer: Kimetsu no Yaiba Infinity Castle
# ...     ...      ...                                             ...
# 9995  False   728949                                      Nightbitch
# 9996  False    10154                                Mickey Blue Eyes
# 9997  False     2959                                  License to Wed
# 9998  False   485811                                        Redcon-1
# 9999  False   397422                                     Rough Night
#
#      original_language                                           overview  \
# ...

# %%
#Web Scraping
from bs4 import BeautifulSoup
pip install lxml
# Out:
#   Cell In[131], line 3
#     python -m pip install lxml
#               ^
# SyntaxError: invalid syntax

# %%
webpage=requests.get("https://atcoder.jp/home").text

soup=BeautifulSoup(webpage,'lxml')
# Out:
# ---------------------------------------------------------------------------
# FeatureNotFound                           Traceback (most recent call last)
# Cell In[129], line 3
#       1 webpage=requests.get("https://atcoder.jp/home").text
# ----> 3 soup=BeautifulSoup(webpage,'lxml')
#
# File ~/Developer/python/ml/lib/python3.11/site-packages/bs4/__init__.py:366, in BeautifulSoup.__init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     364     possible_builder_class = builder_registry.lookup(*features)
#     365     if possible_builder_class is None:
# --> 366         raise FeatureNotFound(
#     367             "Couldn't find a tree builder with the features you "
#     368             "requested: %s. Do you need to install a parser library?"
#     369             % ",".join(features)
#     370         )
#     371     builder_class = possible_builder_class
# ...
