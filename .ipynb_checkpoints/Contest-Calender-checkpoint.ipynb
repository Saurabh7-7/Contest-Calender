# %%
from bs4 import BeautifulSoup
import requests
from datetime import datetime
from zoneinfo import ZoneInfo
from datetime import datetime, timedelta
import pandas as pd

# %%
atcoder_page=requests.get("https://atcoder.jp/home").text
atcoder_soup=BeautifulSoup(atcoder_page,'lxml')

# %%
div_tag=atcoder_soup.find_all('div',id='contest-table-upcoming')

# %%
tr_tags=div_tag[0].find_all('tr')
tr_tags.pop(0)
atcoder_contests=[]

for tr in tr_tags:
    td=tr.find_all('td')
    time=td[0].find('time').text.strip()
    contest_name=td[1].find('a').text.strip()
    link ="https://atcoder.jp" + td[1].find('a')['href']
    
    
    dt = datetime.strptime(time, "%Y-%m-%d %H:%M:%S%z")
    dt = dt - timedelta(hours=3, minutes=30)

    time = dt.strftime("%Y-%m-%d %H:%M:%S")

    atcoder_contests.append([time,contest_name,link])

# %%
df=pd.DataFrame(atcoder_contests,columns=['time','contest_name','link'])
df
# Out:
#                   time                                       contest_name  \
# 0  2026-09-26 17:30:00  UNICORNProgramming Contest2026(AtCoder Beginne...
# 1  2026-09-27 17:30:00                          AtCoder Grand Contest 078
# 2  2026-10-03 17:30:00                       AtCoder Beginner Contest 478
# 3  2026-10-04 17:30:00                        AtCoder Regular Contest 231
# 4  2026-10-10 17:30:00                      AtCoder Regular Contest++ 232
# 5  2026-10-11 17:30:00                       AtCoder Beginner Contest 479
# 6  2026-10-12 09:30:00                AAL Contest 001: Let's use segtree!
#
#                                   link
# 0   https://atcoder.jp/contests/abc477
# 1   https://atcoder.jp/contests/agc078
# 2   https://atcoder.jp/contests/abc478
# 3   https://atcoder.jp/contests/arc231
# 4   https://atcoder.jp/contests/arc232
# 5   https://atcoder.jp/contests/abc479
# 6  https://atcoder.jp/contests/aalc001

# %%
headers = {"User-Agent": "Mozilla/5.0"}
response = requests.get("https://www.codechef.com/api/list/contests/all", headers=headers)
data = response.json()

codechef_contests = []

for contest in data["future_contests"]:

    contest_code = contest["contest_code"]
    contest_name = contest["contest_name"]
    date_time = contest["contest_start_date_iso"]
    duration = contest["contest_duration"]

    link = "https://www.codechef.com/" + contest_code

    codechef_contests.append([
        contest_code,
        contest_name,
        date_time,
        duration,
        link
    ])

codechef_contests = pd.DataFrame(
    codechef_contests,
    columns=[
        "contest_code",
        "contest_name",
        "date_time",
        "duration",
        "link"
    ]
)

codechef_contests
# Out:
#    contest_code                              contest_name  \
# 0  DSAMONDAY022  Monday Munch - DSA Challenge 022 (Rated)
# 1      START258                              Starters 258
#
#                    date_time duration                                   link
# 0  2026-09-28T19:00:00+05:30      180  https://www.codechef.com/DSAMONDAY022
# 1  2026-09-30T20:00:00+05:30      120      https://www.codechef.com/START258
